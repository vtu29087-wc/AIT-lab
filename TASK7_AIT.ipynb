# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu29087-wc/AIT-lab/blob/main/TASK7_AIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey = "window"
box  = "window"
banana = "false"
print("monkey walks to box")
print("monkey pushes box under bananas")
box = "under banana"
print("monkey climbs box")
print("monkey grap&banana")
banana = True
print("Goal achieved:",banana)
# Out:
# monkey walks to box
# monkey pushes box under bananas
# monkey climbs box
# monkey grap&banana
# Goal achieved: True
