# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu29087-wc/AIT-lab/blob/main/TASK5_AIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R1 = 30
R2 = 70
Total = R1+R2
P1 = R1/Total
P2 = R2/Total
print("R1 =",R1)
print("R2 =",R2)
print("Total =",Total)
print("P1 =",P1)
print("P2 =",P2)
if P1 > P2:
  print("Best Route:", R1)
else:
  print("Best Route:", R2)
  print("P1+P2=", P1+P2)
# Out:
# R1 = 30
# R2 = 70
# Total = 100
# P1 = 0.3
# P2 = 0.7
# Best Route: 70
# P1+P2= 1.0
